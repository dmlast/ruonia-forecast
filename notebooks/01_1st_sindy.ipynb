# %%
import sys, pathlib, datetime as dt

# 1) добавляем src/ в путь
PROJECT_ROOT = pathlib.Path.cwd().parents[0]
sys.path.append(str(PROJECT_ROOT / "src"))

# 2) импорт и запуск DataMerger
from data.merged_data import DataMerger

merger = DataMerger(start_date=dt.date(2011,1,1), end_date=dt.date.today())
df_merged = merger.merge()

# 3) смотрим первые строки и список колонок
print(df_merged.columns.tolist())
df_merged[['DATE','1W','ruonia']].head()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /opt/anaconda3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /opt/anaconda3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /opt/anaconda3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-07-07 16:56:21,113 - moex_fetcher - INFO - Выполняется запрос с позиции 0
# ...

# %%
df_merged[['DATE','1W', '2W', 'ruonia']].tail()
# Out:
#             DATE     1W     2W  ruonia
# 4631  2025-07-02  19.97  19.95   20.06
# 4632  2025-07-03  19.96  19.95   19.99
# 4633  2025-07-04  19.96  19.95    <NA>
# 4634  2025-07-05   <NA>   <NA>    <NA>
# 4635  2025-07-07   <NA>   <NA>    <NA>
